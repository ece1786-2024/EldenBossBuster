# %%
from googleapiclient.discovery import build

api_key = 'AIzaSyAnqrLmb525xrwXqSbNOPno_ay4bKESYBA'
playlist_ids = [
    'PLyT5NcCVqdX_IpNzjf5izT0jwJJf01jOU',
    'PLqpGk7JGu_zyv3EM2OEFBeydZG7B3Ya_A',
    'PLvr_yz_u6YtzOYDAxwrQ3G_GAxatPqYsF',
    'PLr4TMm2srxnwrq5Zq2BcKPV2S5tJqlRSq',   
]

youtube = build('youtube', 'v3', developerKey=api_key)

# %%
#  retrieve video IDs and titles from the playlist
def get_video_details_from_playlist(playlist_id):
    video_details = []
    request = youtube.playlistItems().list(
        part='contentDetails,snippet',
        playlistId=playlist_id,
        maxResults=50
    )
    while request:
        response = request.execute()
        for item in response['items']:
            video_id = item['contentDetails']['videoId']
            title = item['snippet']['title']
            video_details.append((video_id, title))
        request = youtube.playlistItems().list_next(request, response)
    return video_details

# retrieve transcripts and add video titles
def get_transcripts_with_titles(video_details):
    transcripts = {}
    for video_id, title in video_details:
        try:
            transcript = YouTubeTranscriptApi.get_transcript(video_id)
            combined_text = " ".join([entry['text'] for entry in transcript])
            transcripts[video_id] = {'title': title, 'text': combined_text}
        except Exception as e:
            print(f"Could not retrieve transcript for video ID {video_id}: {e}")
    return transcripts

all_transcripts = {}
for playlist_id in playlist_ids:
    print(f"Processing playlist: {playlist_id}")
    video_details = get_video_details_from_playlist(playlist_id)
    transcripts_with_titles = get_transcripts_with_titles(video_details)
    all_transcripts.update(transcripts_with_titles)
# Out:
# Processing playlist: PLyT5NcCVqdX_IpNzjf5izT0jwJJf01jOU
# Processing playlist: PLqpGk7JGu_zyv3EM2OEFBeydZG7B3Ya_A
# Could not retrieve transcript for video ID XdWmiJVSYhQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=XdWmiJVSYhQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processing playlist: PLvr_yz_u6YtzOYDAxwrQ3G_GAxatPqYsF
# Processing playlist: PLr4TMm2srxnwrq5Zq2BcKPV2S5tJqlRSq

# %%
# save transcripts with titles to a file
with open('data/raw_transcripts_boss.txt', 'w', encoding='utf-8') as file:
    for video_id, data in all_transcripts.items():
        title = data['title']
        text = data['text']
        file.write(f"Title: {title}\nVideo ID: {video_id}\nTranscript Text:\n{text}\n\n")

# %%
file_path = 'data/raw_transcripts_boss.txt'

with open(file_path, 'r', encoding='utf-8') as file:
    content = file.read()

# %%
import re

# split the content into sections by each title
sections = re.split(r"Title: ", content)[1:]  # The first split part is empty, skip it.

# %%
parsed_data = []
for section in sections:
    title_match = re.search(r"(.*?)\n", section)
    video_id_match = re.search(r"Video ID: (.*?)\n", section)
    transcript_match = re.search(r"Transcript Text:\n(.*)", section, re.S)

    if title_match and video_id_match and transcript_match:
        parsed_data.append({
            "Title": title_match.group(1).strip(),
            "Video ID": video_id_match.group(1).strip(),
            "Transcript": transcript_match.group(1).strip()
        })

# %%
print(len(parsed_data))
# Out:
# 327

# %%
import openai
import os
openai.api_key = os.environ["OPENAI_API_KEY"]

# %%
def clean_transcript_for_rag(title, video_id, transcript):
    prompt = f"""
    This is a transcript of a boss fight guide for Elden Ring. Your task is to extract structured information about the boss fight while ensuring the boss’s name is explicitly referenced throughout the output.

    Input:
    - Video Title: {title}
    - Transcript: {transcript}

    Task:
    1. Summarize the key strategy for defeating the boss, explicitly mentioning the boss name throughout.
    2. List the recommended equipment, abilities, or techniques, ensuring they are tied to the boss name wherever relevant.
    3. Provide specific tips for melee and ranged builds, explicitly mentioning the boss name in the tips.
    4. Structure the output with the following headings, ensuring the boss name appears in each section:
    
    """
    
    response = openai.chat.completions.create(
        model="gpt-4o-mini",  # or "gpt-4-turbo" if available
        messages=[
        {
            "role": "user",
            "content": prompt
        }
    ]
    )
    
    return response.choices[0].message.content.strip()

# example usage with the first entry
first_guide = parsed_data[0]
structured_guide = clean_transcript_for_rag(first_guide["Title"], first_guide["Video ID"], first_guide["Transcript"])

print(structured_guide)
# Out:
# # Boss Strategy for Defeating Rennala, Queen of the Full Moon
#
# To defeat Rennala, Queen of the Full Moon, the key strategy involves breaking the aura of her students in phase one. You need to hit the student with a glowing aura once to reveal Rennala. Repeat this process for three students to drop Rennala's health significantly. Avoid killing all the students before breaking the aura, as it could lead to more chaotic positioning in the arena. Once you've reduced half of Rennala's health, prepare for the second phase by buffing your weapon and attacking aggressively to finish her off in the same manner.
#
# ## Recommended Equipment and Abilities for Defeating Rennala, Queen of the Full Moon
#
# 1. **Spirit Ashes**: Summoning wolf spirit ashes is highly recommended when facing Rennala. This allows for consistent staggering against her.
# 2. **Bleed Weapons**: Upgrading a melee weapon that can inflict bleed damage is beneficial for defeating Rennala, Queen of the Full Moon.
# 3. **Holy Damage**: If available, using holy damage can also be quite effective against Rennala.
# 4. **Health Flasks**: Stock up on health flasks for the fight with Rennala, as you will need them more than mana flasks.
#
# ## Tips for Melee Builds Against Rennala, Queen of the Full Moon
#
# For melee builds attempting to defeat Rennala, Queen of the Full Moon, the best approach is to upgrade your melee weapon to at least +6 and incorporate abilities like Bloody Slash. Position yourself effectively by having spirit wolves on one side and yourself on the other to maximize damage without taking too much damage in return. Remain aggressive and utilize dodge mechanics to avoid her attacks while continually attacking Rennala.
#
# ## Tips for Ranged Builds Against Rennala, Queen of the Full Moon
#
# For ranged builds, be aware that direct magic attacks may not be as effective against Rennala, Queen of the Full Moon, since she has magic resistance. Instead, consider switching to more direct melee strategies or using a melee weapon with special abilities. If you choose to summon spirit ashes, wait for Rennala to cast her beam attack before summoning to avoid being hit. Focus on dodging her spells and positioning yourself to minimize damage while attacking when possible.

# %%
output_txt_path = "data/structured_guides_cleaned.txt"

with open(output_txt_path, "w", encoding="utf-8") as output_file:
    for guide in parsed_data:
            structured_guide = clean_transcript_for_rag(
                guide["Title"], 
                guide["Video ID"], 
                guide["Transcript"]
            )
            output_file.write(f"Title: {guide['Title']}\n")
            output_file.write(f"{structured_guide}\n")
            output_file.write("\n" + "="*80 + "\n\n")

# %%
### Equipment Guide ###

# %%
equiment_transcripts = {}
playlist_id = 'PLyT5NcCVqdX_V_f4l1Fpl18hHXiuhwOCf'
print(f"Processing playlist: {playlist_id}")
video_details = get_video_details_from_playlist(playlist_id)
transcripts_with_titles = get_transcripts_with_titles(video_details)
equiment_transcripts.update(transcripts_with_titles)
# Out:
# Processing playlist: PLyT5NcCVqdX_V_f4l1Fpl18hHXiuhwOCf

# %%
with open('data/raw_transcripts_equipment.txt', 'w', encoding='utf-8') as file:
    for video_id, data in equiment_transcripts.items():
        title = data['title']
        text = data['text']
        file.write(f"Title: {title}\nVideo ID: {video_id}\nTranscript Text:\n{text}\n\n")

# %%
file_path = 'data/raw_transcripts_equipment.txt'
with open(file_path, 'r', encoding='utf-8') as file:
    content = file.read()
sections = re.split(r"Title: ", content)[1:]
parsed_data_equipment = []
for section in sections:
    title_match = re.search(r"(.*?)\n", section)
    video_id_match = re.search(r"Video ID: (.*?)\n", section)
    transcript_match = re.search(r"Transcript Text:\n(.*)", section, re.S)

    if title_match and video_id_match and transcript_match:
        parsed_data_equipment.append({
            "Title": title_match.group(1).strip(),
            "Video ID": video_id_match.group(1).strip(),
            "Transcript": transcript_match.group(1).strip()
        })

# %%
# Function to clean the equipment transcripts using the designed prompt
def clean_equipment_transcript(title, video_id, transcript):
    prompt = f"""
    This is a transcript from an Elden Ring equipment guide video. Your task is to extract and structure information about the equipment discussed, including specific weapons, their strengths and weaknesses, and the ideal use cases.

    Input:
    - Video Title: {title}
    - Transcript: {transcript}

    Task:
    1. Identify each piece of equipment (e.g., weapons, armor, talismans) mentioned in the transcript and summarize its key characteristics.
    2. Highlight the strengths and weaknesses of the equipment in concise bullet points.
    3. Recommend specific builds or playstyles where this equipment would excel, mentioning compatibility with attributes or other equipment.
    4. Structure the output under the following headings:

    """
    
    response = openai.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
        {
            "role": "user",
            "content": prompt
        }
    ]
    )
    
    return response.choices[0].message.content.strip()

# example usage with the first entry
first_guide = parsed_data_equipment[0]
structured_guide = clean_equipment_transcript(first_guide["Title"], first_guide["Video ID"], first_guide["Transcript"])

print(structured_guide)
# Out:
# # Elden Ring Greatsword Equipment Guide
#
# ## 1. Alabaster Lord Sword
# - **Characteristics:**
#   - Lightest greatsword (8 weight)
#   - Deals physical and magic damage.
#   - Requires points in Strength, Dexterity, and Intelligence.
#
# - **Strengths:**
#   - Highest physical damage among magic/cold infused greatswords.
#   - Bonus damage to gravity-type enemies.
#   - Excellent strength scaling.
#   - Can acquire two without player drops.
#
# - **Weaknesses:**
#   - Shorter than most greatswords.
#   - Second lowest magic damage among magic/cold infused greatswords.
#   - Poor dexterity and intelligence scaling.
#   - Try to power stance with two copies for lowered equip load.
#
# - **Recommended Builds:**
#   - Primarily suited for pure Strength builds.
#   - Use alongside a greatshield for block-counter strategies or dual-wielding for added versatility.
#
# ## 2. Ordovis's Greatsword
# - **Characteristics:**
#   - Weighs 12.
#   - Deals physical and holy damage.
#   - Requires Strength, Dexterity, and Faith.
#
# - **Strengths:**
#   - Highest attack rating among heavy infused greatswords.
#   - Powerful AoE weapon skill, Ordovis's Vortex.
#   - Can be charged for increased damage.
#
# - **Weaknesses:**
#   - High Faith requirements with poor scaling.
#   - Acquired later in the game (Ariza Hiro's Grave).
#   - Poor scaling in NG+.
#
# - **Recommended Builds:**
#   - Best for Strength-focused builds with minimal investment in Faith (25 recommended) for buffs like Golden Vow.
#   - Consider using in conjunction with a greatshield for enhanced playstyle.
#
# ## 3. Inseparable Sword
# - **Characteristics:**
#   - Average weight (10).
#   - Deals physical and holy damage.
#   - Requires Strength, Dexterity, and Faith.
#
# - **Strengths:**
#   - +20 damage to undead enemies.
#   - Unique in preventing undead revival.
#   - High attack rating at high Faith (80).
#
# - **Weaknesses:**
#   - Low physical damage output compared to other holy greatswords.
#   - Poor scaling and less effective in late-game due to boss resistances.
#
# - **Recommended Builds:**
#   - Focus on high Faith builds for its attack rating advantage and unique abilities.
#   - Ideal as part of a holy-themed playstyle or paired with a sacred seal for casting.
#
# ## 4. Gargoyle's Black Blade
# - **Characteristics:**
#   - Weighs 11.5.
#   - Deals physical and holy damage.
#   - Requires Strength, Dexterity, and Faith.
#
# - **Strengths:**
#   - Highest holy damage attack rating at 50 Faith and Strength.
#   - Powerful weapon skill, Corpse Wax Cutter.
#   - Can inflict serious damage with minimal investment.
#
# - **Weaknesses:**
#   - Poor scaling limits its effectiveness in later stages.
#   - Difficult to acquire early on.
#
# - **Recommended Builds:**
#   - Best for a hybrid Strength and Faith build (50/50).
#   - Can be effectively utilized in block-counter builds with a shield.
#
# ## 5. Sword of Milos
# - **Characteristics:**
#   - Average weight (10).
#   - Deals physical damage.
#   - Requires Strength and Dexterity.
#
# - **Strengths:**
#   - Restores FP per kill.
#   - Good quality scaling, effective in both Strength and Dexterity builds.
#
# - **Weaknesses:**
#   - Buff duration is short.
#   - Only useful if combined with another bleed weapon for maximum effect.
#
# - **Recommended Builds:**
#   - Synergizes well in setups skilled for bleed effects and off-hand recovery.
#   - High quality scaling enables a versatile build strategy.
#
# ## 6. Moray Executioner's Sword
# - **Characteristics:**
#   - Heavier greatsword (11.5).
#   - Deals physical and magic damage.
#   - Requires Strength, Dexterity, and Arcane.
#
# - **Strengths:**
#   - Strong AoE skill, AoJ's Dancing Blade.
#   - Can be significantly buffed with various talismans.
#
# - **Weaknesses:**
#   - Low magic damage output among its peers.
#   - High skill requirements can restrict playstyle options.
#
# - **Recommended Builds:**
#   - Suitable for builds that effectively utilize both melee and magic casting.
#   - Invest in both Strength and Arcane (50/50).
#
# ## 7. Death's Poker
# - **Characteristics:**
#   - Lightweight (8.5).
#   - Deals physical and magic damage.
#   - Requires Strength, Dexterity, and Intelligence.
#
# - **Strengths:**
#   - Builds frostbite with each hit.
#   - Low requirements and high base damage.
#
# - **Weaknesses:**
#   - Lowest magic damage dealing capacity among peers.
#   - Scaling issues limit effective magic damage usage.
#
# - **Recommended Builds:**
#   - Ideal for fast-paced melee combat focusing on frostbite application.
#   - Pair with spells for maximum versatility (50 Strength, 20 Intelligence recommended).
#
# ## 8. Hellfin Steeple
# - **Characteristics:**
#   - Weighs 11.5.
#   - Deals physical and magic damage.
#   - Requires Strength, Dexterity, and Intelligence.
#
# - **Strengths:**
#   - Highest attack rating among magic-infused greatswords.
#   - Buffs magic damage while adding frostbite.
#
# - **Weaknesses:**
#   - Average intelligence scaling compared to other damage-infused options.
#
# - **Recommended Builds:**
#   - Best in dual-wield setups or as part of a jump attack playstyle.
#   - Focus on equal Strength and Intelligence (50/50) for optimal performance.
#
# ## 9. Blasphemous Blade
# - **Characteristics:**
#   - Heaviest (13.5).
#   - Deals physical and fire damage.
#   - Requires Strength, Dexterity, and Faith.
#
# - **Strengths:**
#   - High potential attack rating with healing capabilities from Taker’s Flame.
#   - Hard-hitting weapon skill benefits from fire damage buffs.
#
# - **Weaknesses:**
#   - High FP cost for weapon skill usage.
#   - Heavy, limiting overall mobility.
#
# - **Recommended Builds:**
#   - Effective in builds high in Strength and DEX (50/50/50) for maximum potential damage.
#   - Strong synergy with fire damage buffs.
#
# ## 10. Darkmoon Greatsword
# - **Characteristics:**
#   - Average weight (10).
#   - Deals physical and magic damage.
#   - Requires high intelligence.
#
# - **Strengths:**
#   - Highest magic damage output among greatswords.
#   - Stagger-inducing charged attacks at range.
#
# - **Weaknesses:**
#   - Requires substantial investment in Intelligence.
#   - Needs frequent buffing for optimal use.
#
# - **Recommended Builds:**
#   - Best for dedicated spellblade builds utilizing high intelligence.
#   - Pair with sorcery improvements for additional damage boosts.
#
# ## 11. Sacred Relic Sword
# - **Characteristics:**
#   - Weighs 11.
#   - Deals physical and holy damage.
#   - Requires Strength, Dexterity, and Faith.
#
# - **Strengths:**
#   - Wave of Gold has devastating damage potential.
#   - Highest attack rating among Keen scaling greatswords.
#
# - **Weaknesses:**
#   - Acquired late in the game.
#   - Limited utility early on due to high stat requirements.
#
# - **Recommended Builds:**
#   - Ideal for Faith-centric builds (55 dexterity and 50 faith).
#   - Best paired with high-damage dual greatsword setups.
#
# ## 12. Bastard Sword
# - **Characteristics:**
#   - Lightweight (9).
#   - Deals physical damage.
#   - Requires Strength and Dexterity.
#
# - **Strengths:**
#   - Very low stat requirements.
#   - Early game availability.
#   - Versatile with many infusions.
#
# - **Weaknesses:**
#   - Average performance in most scenarios.
#
# - **Recommended Builds:**
#   - Ideal as a starter weapon for versatile builds.
#   - Works well with various ashes of war for customization.
#
# ## 13. Claymore
# - **Characteristics:**
#   - Weighs 9.
#   - Deals physical damage.
#   - Requires Strength and Dexterity.
#
# - **Strengths:**
#   - Early game availability.
#   - Unique thrust R2 for extended reach.
#
# - **Weaknesses:**
#   - Average damage in comparison to other greatswords.
#
# - **Recommended Builds:**
#   - Best for players experimenting with Ashes of War.
#   - Can be effective in dexterity-oriented builds.
#
# ## 14. Iron Greatsword
# - **Characteristics:**
#   - Heavy (12).
#   - Deals physical damage.
#   - Requires Strength and Dexterity.
#
# - **Strengths:**
#   - Highest base physical damage.
#   - Versatile for various builds and infusions.
#
# - **Weaknesses:**
#   - Hard to obtain until reaching the Royal Capital.
#
# - **Recommended Builds:**
#   - Strong option for all builds due to its infusion flexibility.
#   - Can serve as a reliable main hand weapon across various playstyles.
#
# ## 15. Lord Sworn's Greatsword
# - **Characteristics:**
#   - Lightweight (9).
#   - Deals physical damage.
#   - Requires Strength and Dexterity.
#
# - **Strengths:**
#   - Earliest attainable greatsword.
#   - Higher critical hit rating.
#
# - **Weaknesses:**
#   - Low overall damage capacity.
#
# - **Recommended Builds:**
#   - Great for speedy early-game builds.
#   - Useful for critical hit setups, paired with ashes of war.
#
# ## 16. Knight's Greatsword
# - **Characteristics:**
#   - Average weight (10).
#   - Deals physical damage.
#   - Requires Strength and Dexterity.
#
# - **Strengths:**
#   - High attack rating early on.
#   - Easily obtainable.
#
# - **Weaknesses:**
#   - Outperformed by Banished Knight’s Greatsword.
#
# - **Recommended Builds:**
#   - Best for early-game efficiency and low-level co-op play.
#   - Powerful option for quick farming.
#
# ## 17. Banished Knight's Greatsword
# - **Characteristics:**
#   - Average weight (10).
#   - Deals physical damage.
#   - Requires Strength and Dexterity.
#
# - **Strengths:**
#   - High attack rating and early availability.
#
# - **Weaknesses:**
#   - Can take time to farm multiple.
#
# - **Recommended Builds:**
#   - King of early-game greatswords.
#   - Excellent for aggressive low-level builds.
#
# ## 18. Forked Greatsword
# - **Characteristics:**
#   - Lightweight (9).
#   - Deals physical damage.
#   - Requires Strength and Dexterity.
#
# - **Strengths:**
#   - Triggers bleed build-up.
#   - Early-game availability.
#
# - **Weaknesses:**
#   - Lower attack rating.
#
# - **Recommended Builds:**
#   - Solid option for bleed-focused builds and quick encounters.
#   - Can pair with other weapons for dual status effects.
#
# ## 19. Flamburge
# - **Characteristics:**
#   - Average weight (10).
#   - Deals physical damage.
#   - Requires Strength and Dexterity.
#
# - **Strengths:**
#   - Triggers bleed build-up.
#   - Excellent scaling in keen builds.
#
# - **Weaknesses:**
#   - Lower overall damage output.
#
# - **Recommended Builds:**
#   - Efforts in dexterity and bleed builds.
#   - Best paired with quick-attack ashes of war.
#
# ## 20. Gargoyle’s Greatsword
# - **Characteristics:**
#   - Heavy (11.5).
#   - Deals physical damage.
#   - Requires Strength and Dexterity.
#
# - **Strengths:**
#   - Exceptional scaling potential.
#
# - **Weaknesses:**
#   - Long to acquire.
#
# - **Recommended Builds:**
#   - Focus on high stats to maximize damage potential.
#   - Works well with dual-wield setups for higher attack numbers.
#
# This guide highlights the key characteristics, strengths, weaknesses, and optimal builds for the various greatswords in Elden Ring, supporting players in selecting the best weapons for their playstyle.

# %%
output_txt_path = "data/structured_equipments_guides_cleaned.txt"

with open(output_txt_path, "w", encoding="utf-8") as output_file:
    for guide in parsed_data_equipment:
            structured_guide = clean_equipment_transcript(
                guide["Title"], 
                guide["Video ID"], 
                guide["Transcript"]
            )
            output_file.write(f"Title: {guide['Title']}\n")
            output_file.write(f"{structured_guide}\n")
            output_file.write("\n" + "="*80 + "\n\n")
